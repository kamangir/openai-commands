# %% [markdown]
# # image generation
#
# using https://platform.openai.com/docs/guides/images/usage?context=python

# %%
import sys
sys.path.append("../")

from blueflow import notebooks

from blue_options import string
from blue_objects import objects

from openai_commands.host import signature
from openai_commands.image_generation.api import OpenAIImageGenerator
from openai_commands.logger import logger

logger.info(f"{'.'.join(signature())},\nbuilt on {string.pretty_date()}")
# Out:
# 🛠️  openai_commands-3.212.1.blueflow-4.849.1.abcli-9.486.1.blue_objects-5.281.1.blue_options-4.200.1.torch-2.5.1.Python 3.9.6.Darwin 23.6.0..Jupyter-Notebook,
# built on 01 February 2025, 12:55:46

# %% [markdown]
# ---

# %%
prompt = "a person flying through the streets of Vancouver."

# %%
object_name = objects.unique_object("openai-images")
filename = objects.path_of(f"{string.timestamp()}.png",object_name)
# Out:
# 🌀  📂 openai-images-2025-02-01-12-55-46-4jda70

# %%
generator = OpenAIImageGenerator(verbose=True)
# Out:
# 🛠️  OpenAIImageGenerator[dall-e-3]

# %%
success, response = generator.generate(
    prompt=prompt,
    filename=filename)

assert success
# Out:
# 🛠️  OpenAIImageGenerator.generate: a person flying through the streets of Vancouver. -> openai-images-2025-02-01-12-55-46-4jda70/2025-02-01-12-55-46-r50yky.png
# httpx HTTP Request: POST https://api.openai.com/v1/images/generations "HTTP/1.1 200 OK"
# 🛠️  {
#     "created": 1738443358,
#     "data": [
#         {
#             "b64_json": null,
#             "revised_prompt": "An image depicts an exciting moment where a person, with no particular gender or descent specified, is seen flying through the streets of Vancouver. With the magnificent cityscape providing a stunning backdrop, the individual flies with arms outstretched in the posture of a bird. He or she skims above sleek vehicles, grazes past neon billboards, and whirls past towering buildings. This urban aerial voyage captures the exhilarating beauty of Vancouver - from the bustling streets lined with modern architecture to the azure sky overhead.",
#             "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-1RdONq0eTlgUUnFpmb7DZuWr/user-id8j8e4QMrQ8PpTpUxwnF9Cr/img-Jfb7IaMUc2SmxL7CYrNrbPxA.png?st=2025-02-01T19%3A55%3A58Z&se=2025-02-01T21%3A55%3A58Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-02-01T00%3A13%3A02Z&ske=2025-02-02T00%3A13%3A02Z&sks=b&skv=2024-08-04&sig=DLhof9GD7l5FZUIquqnde9JFplwMkuUSGF2fXX8gIKU%3D"
#         }
#     ]
# }
# 🌀  blue_objects.file.functions: https://oaidalleapiprodscus.blob.core.windows.net/private/org-1RdONq0eTlgUUnFpmb7DZuWr/user-id8j8e4QMrQ8PpTpUxwnF9Cr/img-Jfb7IaMUc2SmxL7CYrNrbPxA.png?st=2025-02-01T19%3A55%3A58Z&se=2025-02-01T21%3A55%3A58Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-02-01T00%3A13%3A02Z&ske=2025-02-02T00%3A13%3A02Z&sks=b&skv=2024-08-04&sig=DLhof9GD7l5FZUIquqnde9JFplwMkuUSGF2fXX8gIKU%3D -> /Users/kamangir/storage/abcli/openai-images-2025-02-01-12-55-46-4jda70/2025-02-01-12-55-46-r50yky.png
# 🌀  -> /Users/kamangir/storage/abcli/openai-images-2025-02-01-12-55-46-4jda70/2025-02-01-12-55-46-r50yky.png

# %% [markdown]
# ---

# %%
assert objects.upload(object_name)
# Out:
# upload: ../../../storage/abcli/openai-images-2025-02-01-12-55-46-4jda70/2025-02-01-12-55-46-r50yky.png to s3://kamangir/bolt/openai-images-2025-02-01-12-55-46-4jda70/2025-02-01-12-55-46-r50yky.png

# %%
# END
