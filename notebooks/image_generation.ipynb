# %% [markdown]
# # image generation
#
# using https://platform.openai.com/docs/guides/images/usage?context=python

# %%
import sys
sys.path.append("../")

from blueflow import notebooks

from blue_options import string
from blue_objects import objects

from openai_commands.host import signature
from openai_commands.image_generation.api import generate_image
from openai_commands.logger import logger

logger.info(f"{'.'.join(signature())},\nbuilt on {string.pretty_date()}")
# Out:
# 🛠️  openai_commands-3.243.1.blueflow-4.849.1.abcli-9.486.1.blue_objects-5.283.1.blue_options-4.207.1.torch-2.5.1.Python 3.9.6.Darwin 23.6.0..Jupyter-Notebook,
# built on 04 February 2025, 12:02:45

# %% [markdown]
# ---

# %%
prompt = "a person flying through the streets of Vancouver."

# %%
object_name = objects.unique_object("openai-images")
filename = f"{string.timestamp()}.png"
# Out:
# 🌀  📂 openai-images-2025-02-04-12-02-45-xiekzd

# %%
success, response = generate_image(
    prompt=prompt,
    filename=filename,
    object_name=object_name,
    verbose=True,
    )

assert success
# Out:
# 🛠️  openai_commands.image_generation.api.generate_image: a person flying through the streets of Vancouver. -> openai-images-2025-02-04-12-02-45-xiekzd/2025-02-04-12-02-45-1p65xf.png
# httpx HTTP Request: POST https://api.openai.com/v1/images/generations "HTTP/1.1 200 OK"
# 🛠️  {
#     "created": 1738699380,
#     "data": [
#         {
#             "b64_json": null,
#             "revised_prompt": "Visualize a Caucasian male, agilely soaring through the bustling streets of Vancouver. He is elegantly swaying around high-rise buildings, under archways, and over well-maintained gardens. Streetlights cast a soft glow on his path, silhouetting him against the inky blue evening sky. Pedestrians below gape in awe as the figure enlivens the skyline. In the backdrop, the cityscape provides a vibrant tableau with iconic buildings and bustling traffic, encapsulating the energy and dynamics of urban life.",
#             "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-1RdONq0eTlgUUnFpmb7DZuWr/user-id8j8e4QMrQ8PpTpUxwnF9Cr/img-WFlVzWInzUx2AJaveOFPQCFD.png?st=2025-02-04T19%3A03%3A00Z&se=2025-02-04T21%3A03%3A00Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-02-04T00%3A33%3A15Z&ske=2025-02-05T00%3A33%3A15Z&sks=b&skv=2024-08-04&sig=kdsUGohfTi9J1UPFriGg5qlnYDJQGzZOejfsbkRv2KY%3D"
#         }
#     ]
# }
# 🌀  blue_objects.file.functions: https://oaidalleapiprodscus.blob.core.windows.net/private/org-1RdONq0eTlgUUnFpmb7DZuWr/user-id8j8e4QMrQ8PpTpUxwnF9Cr/img-WFlVzWInzUx2AJaveOFPQCFD.png?st=2025-02-04T19%3A03%3A00Z&se=2025-02-04T21%3A03%3A00Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-02-04T00%3A33%3A15Z&ske=2025-02-05T00%3A33%3A15Z&sks=b&skv=2024-08-04&sig=kdsUGohfTi9J1UPFriGg5qlnYDJQGzZOejfsbkRv2KY%3D -> /Users/kamangir/storage/abcli/openai-images-2025-02-04-12-02-45-xiekzd/2025-02-04-12-02-45-1p65xf.png
# 🌀  -> /Users/kamangir/storage/abcli/openai-images-2025-02-04-12-02-45-xiekzd/2025-02-04-12-02-45-1p65xf.png

# %% [markdown]
# ---

# %%
assert notebooks.upload(object_name)
# Out:
# upload: ../../../storage/abcli/openai-images-2025-02-04-12-02-45-xiekzd/2025-02-04-12-02-45-1p65xf.png to s3://kamangir/bolt/openai-images-2025-02-04-12-02-45-xiekzd/2025-02-04-12-02-45-1p65xf.png
# 🌀  ⏺️  openai-images-2025-02-04-12-02-45-xiekzd | 00001
# 🌀  ⬆️  /Users/kamangir/storage/abcli/openai-images-2025-02-04-12-02-45-xiekzd/2025-02-04-12-02-45-1p65xf.png
# 🏃 View run openai-images-2025-02-04-12-02-45-xiekzd-00001 at: https://dbc-3ac1d106-bf0c.cloud.databricks.com/ml/experiments/609088892273240/runs/6f4599ba9a114766ac4c7026eb6e1d88
# 🧪 View experiment at: https://dbc-3ac1d106-bf0c.cloud.databricks.com/ml/experiments/609088892273240
# 🌀  ⏹️  openai-images-2025-02-04-12-02-45-xiekzd

# %%
# END
